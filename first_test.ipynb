# %% [markdown]
# # Test

# %%
import numpy as np
from rdflib import Graph, Namespace, URIRef
# %matplotlib inline
from matplotlib import pyplot

# %%
a = np.array([1,2,3,4,5])
y = np.array([1,2,1,2,1])

# %%
pyplot.plot(a,y)
pyplot.title("A simple Test")
pyplot.text(3,2, r"$\mathcal{O} \models \alpha$", horizontalalignment='center',
     fontsize=20)
pyplot.show()

# %% [markdown]
# $w^TL_{\kappa}w$
